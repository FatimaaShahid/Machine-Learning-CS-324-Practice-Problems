# %% [markdown]
# # Linear Regression Exercises

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ## Problem 1 - Running Gradient Descent on Cost Function of Univariate Linear Regression
#
# ### Mean Squared Error: a cost function for regression problems
#
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1.x^{(i)} \big)^2 $$
#
#
# ### Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %%
#Real data for x and y (dataset with n=7)
x_i = [0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]
y_i = [1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]

# x_i is input and y_i is output

#Making data for theta_0 and theta_1
th_0 = np.linspace(start=-1, stop=3, num=200)
th_1 = np.linspace(start=-1, stop=3, num=200)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %%
#The cost function - MSE
def mse(theta_0,theta_1):
    total=0 #ths is error initialization
    for j in range(len(x_i)):
        total+=(y_i[j]-theta_0-theta_1*x_i[j])**2
    return total/(len(x_i))

#Partial derivative wrt theta_0
def pdtheta_0(theta_1,theta_0):
    total=0
    for j in range(len(x_i)):
        total+=y_i[j]-theta_0-theta_1*x_i[j]
    return 2*total/(-len(x_i))

#Partial derivative wrt theta_1
def pdtheta_1(theta_1,theta_0):
    total=0
    for j in range(len(x_i)):
        total+=(y_i[j]-theta_0-theta_1*x_i[j])*x_i[j]
    return 2*total/(-len(x_i))

# %%
#Gradient descent implementation
learning_rate = 0.01
max_iter = 200
initial_theta_0 =1.18
initial_theta_1= 1

theta_0_old=initial_theta_0
theta_1_old=initial_theta_1

theta_0_list=[]
theta_1_list=[]
for i in range (1,max_iter+1):
    theta_0_new = theta_0_old - learning_rate * pdtheta_0(theta_0_old,theta_1_old)
    theta_1_new = theta_1_old - learning_rate * pdtheta_1(theta_0_old,theta_1_old)

    theta_0_list.append(theta_0_old)
    theta_1_list.append(theta_1_old)

    theta_0_old=theta_0_new
    theta_1_old=theta_1_new

# %%
#Plotting a 3D graph
fig=plt.figure(figsize=[16,12])
ax=plt.axes(projection='3d')
ax.set_xlabel('theta 0', fontsize=16)
ax.set_ylabel('theta 1', fontsize=16)
ax.set_zlabel('Cost - MSE', fontsize=16)
ax.plot_surface(plot_t0, plot_t1, mse(plot_t0, plot_t1), alpha=0.4, cmap='summer')
ax.scatter(theta_0_list,theta_1_list,mse(np.array(theta_0_list),np.array(theta_1_list)), alpha=0.4, s=50, color='red')
plt.show()

# %% [markdown]
# ## Problem 2: Making Predictions using the Movie Revenue Dataset
# ### An Example of Univariate Linear Regression

# %%
#Loading movie revenue dataset from csv
data=pd.read_csv('Dataset_Movie_Revenue_Clean - Dataset_Movie_Revenue_Clean.csv')
data
# Out:
#       Production_Budget  World_Gross
# 0             400000000   2797800564
# 1             379000000   1045713802
# 2             365000000   1395316979
# 3             306000000   2064615817
# 4             300000000   2044540523
# ...                 ...          ...
# 5768               7000        71644
# 5769               7000          900
# 5770               6000       240495
# 5771               5000         1338
# 5772               1100       181041
#
# [5773 rows x 2 columns]

# %%
#Separating the feature into variable X
X=data['Production_Budget'] #extracts column as a series
type(X)
X=data[['Production_Budget']] #extracts column as a dataframe
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
#Separating the target into variable X
Y=data[['World_Gross']]
type(Y)
# Out:
# pandas.core.frame.DataFrame

# %%
#Visualizing Data
plt.figure(figsize=(10,6))
plt.scatter(X,Y,alpha=0.3) #alpha sets transparency of dots
plt.title('Budget vs Revenue',fontsize=14)
plt.xlabel('Movie Budget $',fontsize=14)
plt.ylabel('Movie bRvenue $',fontsize=14)
plt.xticks(color='red',fontsize=14)
plt.yticks(color='red',fontsize=14)
plt.xlim(0,450000000)
plt.ylim(0,1000000000)
plt.show()

# %%
#Fitting Linear Regression Model
r=LinearRegression() #Creates an object of LinearRegression type
r.fit(X,Y) #Does the training to select optimal values of the parameters
# Out:
# LinearRegression()

# %%
#Reading values for parameters theta_0 and theta_1

#theta_0
t0=r.intercept_[0]
#theta_1
t1=r.coef_[0][0]
print('theta_0:',t0)
print('theta_1:',t1)
# Out:
# theta_0: -8702395.435496628
# theta_1: 3.206135399149209

# %%
#Reading R-square value (the goodness of fit)
r.score(X,Y)
# Out:
# 0.5455936700827255

# %%
#Making predictions

#Approach 1: Using the equation of linear regression
y=t0+t1*5000000
print('Prediction 1:',y)

#Approach 2: Using the predict method
y=r.predict(pd.DataFrame([5000000]))
print('Prediction 2:',y)
# Out:
# Prediction 1: 7328281.560249416
# Prediction 2: [[7328281.56024942]]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Making predictions for the whole dataset
y=r.predict(X)
y
# Out:
# array([[ 1.27375176e+09],
#        [ 1.20642292e+09],
#        [ 1.16153703e+09],
#        ...,
#        [-8.68315862e+06],
#        [-8.68636476e+06],
#        [-8.69886869e+06]])

# %% [markdown]
# practice problem 3

# %%
def r_squared(y_true, y_pred):

    ss_res = np.sum((y_true - y_pred)**2)     # residual sum of squares
    ss_tot = np.sum((y_true - np.mean(y_true))**2)  # total sum of squares

    r2 = 1 - (ss_res / ss_tot)

    return r2

# Recalculate y (predicted values for the movie revenue dataset) to ensure correct shape
y_movie_pred = r.predict(X)

r2_score = r_squared(Y, y_movie_pred)

print("\nR-squared:", r2_score)
# Out:
# R-squared: World_Gross    0.545594
# dtype: float64
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
#Plotting the fit line over the scatter plot
plt.figure(figsize=(10,6))
plt.scatter(X,Y,alpha=0.3)
plt.title('Budget vs Revenue',fontsize=14)
plt.xlabel('Movie Budget $',fontsize=14)
plt.ylabel('Movie bRvenue $',fontsize=14)
plt.xticks(color='red',fontsize=14)
plt.yticks(color='red',fontsize=14)
plt.xlim(0,450000000)
plt.ylim(0,1000000000)
plt.plot(X,r.predict(X),color='red',linewidth=4)
plt.show()

# %% [markdown]
# ### An Altenate Model
# ### Applying Data Split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X, Y,test_size=0.2,random_state=0)
print('Size of original dataset (complete):',len(X))
print('Size of train dataset (80%):',len(X_train))
print('Size of test dataset (20%):',len(X_test))
# Out:
# Size of original dataset (complete): 5773
# Size of train dataset (80%): 4618
# Size of test dataset (20%): 1155

# %%
#Let us now fit the model on train data and then check the r_squared value of both train and test sets
r2=LinearRegression()
r2.fit(X_train,Y_train)
print(r2.score(X_train,Y_train))
print(r2.score(X_test,Y_test))
# Out:
# 0.5389128447428836
# 0.5699002688488439

# %% [markdown]
# ##practice problem 4
#  Derive two more models with the following splits and determine which split
# gives the best result.
# Model 2: 70%-30%
# Model 3: 90%-10%

# %% [markdown]
# the 70% train and 30% test model

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X, Y,test_size=0.3,random_state=0)
print('Size of original dataset (complete):',len(X))
print('Size of train dataset (80%):',len(X_train))
print('Size of test dataset (20%):',len(X_test))
r2=LinearRegression()
r2.fit(X_train,Y_train)
print(r2.score(X_train,Y_train))
print(r2.score(X_test,Y_test))
# Out:
# Size of original dataset (complete): 5773
# Size of train dataset (80%): 4041
# Size of test dataset (20%): 1732
# 0.5500131026230372
# 0.5352521542286193

# %% [markdown]
# the 90% train and 10 % test split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X, Y,test_size=0.1,random_state=0)
print('Size of original dataset (complete):',len(X))
print('Size of train dataset (80%):',len(X_train))
print('Size of test dataset (20%):',len(X_test))
r2=LinearRegression()
r2.fit(X_train,Y_train)
print(r2.score(X_train,Y_train))
print(r2.score(X_test,Y_test))
# Out:
# Size of original dataset (complete): 5773
# Size of train dataset (80%): 5195
# Size of test dataset (20%): 578
# 0.5454890388482707
# 0.545066299107799

# %% [markdown]
# since, the score on test and train are close, we can say that model works fine on new data but the score itself is not good. a good score is nearest to 1

# %% [markdown]
# ## Problem 3: Making Predictions using the Boston Housing Dataset
# ### An Example of Multivariable Linear Regression
#
# Refer to notebook 'N4_Data Preprocessing and Feature Engineeing_4.ipynb' for preliminary details on this dataset.

# %%
#Loading the dataset from the csv file
boston_dataset = pd.read_csv('Dataset_Boston - Dataset_Boston.csv')
boston_dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %%
#Creating a series for the target
target=boston_dataset['PRICE']
target
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: PRICE, Length: 506, dtype: float64

# %%
#Creating a dataframe for the features
features=boston_dataset.drop(['PRICE'],axis=1)
features
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
#Splitting sataset into train and test parts
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=10)

# %% [markdown]
# ### TASK FOR YOU
# Find sizes of train and test sets and verify if the split is actually 80%-20%.

# %%
print('Size of original dataset (complete):',len(features))
print('Size of train dataset (80%):',len(X_train))
print('Size of test dataset (20%):',len(X_test))
# Out:
# Size of original dataset (complete): 506
# Size of train dataset (80%): 404
# Size of test dataset (20%): 102

# %%
#Running multivariable linear regression
regr = LinearRegression()
regr.fit(X_train, y_train)

print('Training data r-square:', regr.score(X_train, y_train))
print('Test data r-square:', regr.score(X_test, y_test))

print('Intercept', regr.intercept_)

#Regression coefficients for all features
pd.DataFrame(data=regr.coef_, index=X_train.columns, columns=['coef'])
# Out:
# Training data r-square: 0.750121534530608
# Test data r-square: 0.6709339839115642
# Intercept 36.53305138282431
#               coef
# CRIM     -0.128181
# ZN        0.063198
# INDUS    -0.007576
# CHAS      1.974515
# NOX     -16.271989
# RM        3.108456
# AGE       0.016292
# DIS      -1.483014
# RAD       0.303988
# TAX      -0.012082
# PTRATIO  -0.820306
# B         0.011419
# LSTAT    -0.581626

# %% [markdown]
# ## Testing Significance of a Feature using p_values
#
# - There is no direct method in sklearn package to find p_values, so we are using another package called statsmodel for this purpose.
# - We will have to run the model fitting again using this new package.

# %% [markdown]
# What is p-value?
#
# The p-value is used in statistics to test whether a variable is statistically significant in explaining the target variable.

# %%
#Reproducing the same results using statsmodel package
X_incl_const = sm.add_constant(X_train)# this is to add an additional row for constant (theta_0)

alternate_model = sm.OLS(y_train, X_incl_const)
results = alternate_model.fit()

#Finding p-values
pd.DataFrame({'coef': results.params, 'p-value': round(results.pvalues, 3)})
#Note that the coefficent values are same as the first model m1. Row one shows the value for theta_0.
# Out:
#               coef  p-value
# const    36.533051    0.000
# CRIM     -0.128181    0.000
# ZN        0.063198    0.000
# INDUS    -0.007576    0.905
# CHAS      1.974515    0.033
# NOX     -16.271989    0.000
# RM        3.108456    0.000
# AGE       0.016292    0.262
# DIS      -1.483014    0.000
# RAD       0.303988    0.000
# TAX      -0.012082    0.001
# PTRATIO  -0.820306    0.000
# B         0.011419    0.000
# LSTAT    -0.581626    0.000

# %% [markdown]
# - We know from theory class, if p-value of a feature is < 0.05 then it is significant, otherwise not.
# - So we conclude from the above results that INDUS and AGE are the two features which might not be significant to the model.

# %% [markdown]
# ## Testing for Multicollinearity

# %% [markdown]
# ### Approach 1: Finding correlations among variables

# %%
#Finding correlations between the features and target - tabular form
features.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000

# %%
#Finding correlations between the features and target - graphical heatmap
plt.figure(figsize=(16,10))
sns.heatmap(features.corr(),  annot=True, annot_kws={"size": 14})
sns.set_style('white')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# We conclude the following high correlations may possibly cause multicollinearity:
# - between TAX and RAD
# - between DIS and NOX
# - between DIS and INDUS
# - between DIS and AGE

# %% [markdown]
# ### Approach 2: Finding variance inflation factors
# - Variance Inflation Factor (VIF) can also be reviewed for detection of multicollineairy.
# - This was not discussed in the topic 'Data Preprocessing and Feature Engineering', as its evaluation requires understanding of linear regression.
#
# Description:
# - VIF measures how much of the variation in one variable is explained by the other variable.
# - This is done by running a regression using one of the correlated features as the dependent variable against the other variables as predictor variables.
# - The VIF value can be interpreted as follows:
#
#    If VIF = 1, no correlation exists
#
#    If VIF is between 1 and 5, moderate correlation exists
#
#    If VIF is between 5 and 10, high correlation exists
#
#    If VIF value is >10 then it is problematic.
#
# Formula:
# $$ VIF _{TAX} = \frac{1}{(1 - R ^ 2)} $$
#
# - Since it is calculated separately for each feature, the following is the calculation of VIF for TAX
# $$ TAX = \alpha _0 + \alpha _1 RM + \alpha _2 NOX + ... + \alpha _{12}LSTAT $$
#
# $$ VIF _{TAX} = \frac{1}{(1 - R _{TAX} ^ 2)} $$

# %%
#Finding VIF for 'TAX'
#This method is also from statsmodel package
variance_inflation_factor(exog=X_incl_const.values, exog_idx=10)
#X_incl_const.values gives ndarray version of the dataframe
# Out:
# np.float64(8.508856493040817)

# %%
#Finding VIF for all columns
vif = [] # empty list
for i in range(X_incl_const.shape[1]):
    vif.append(variance_inflation_factor(exog=X_incl_const.values, exog_idx=i))
print(vif)
# Out:
# [np.float64(597.5487126763895), np.float64(1.7145250443932485), np.float64(2.3328224265597584), np.float64(3.943448822674638), np.float64(1.0788133385000576), np.float64(4.410320817897634), np.float64(1.8404053075678573), np.float64(3.3267660823099394), np.float64(4.222923410477865), np.float64(7.314299817005058), np.float64(8.508856493040817), np.float64(1.8399116326514064), np.float64(1.338671325536472), np.float64(2.812544292793036)]

# %% [markdown]
# We conclude that the following two values are high and show possible signs of multicollinearity:
# - 7.314299817005058, corresponds to feature RAD
# - 8.508856493040817, corresponds to feature TAX

# %% [markdown]
# ### Summarizing
# - Possible insignificant features: INDUS and AGE
#
# - Features exhibiting signs of multicollinearity: TAX and RAD (as these were indicated by both methods)
#
#
# - Now let's drop these features one by one and see the results.
# - That means we will create different models with different subset of features, selecting the best model as the final one.

# %%
#Model 1: with all the 13 features
m1 = LinearRegression()
m1.fit(X_train, y_train)
print('With all 13 features:')
print('Training data r-squared:', m1.score(X_train, y_train))
print('Test data r-squared:', m1.score(X_test, y_test))

#Model 2: dropping 'AGE' and 'INDUS'
X_train2=X_train.drop(['AGE','INDUS'],axis=1)
X_test2=X_test.drop(['AGE','INDUS'],axis=1)
m2 = LinearRegression()
m2.fit(X_train2, y_train)
print('\nDropping AGE and INDUS:')
print('Training data r-squared:', m2.score(X_train2, y_train))
print('Test data r-squared:', m2.score(X_test2, y_test))

#Model 3: dropping 'RAD' and 'TAX'
X_train3=X_train.drop(['RAD','TAX'],axis=1)
X_test3=X_test.drop(['RAD','TAX'],axis=1)
m3 = LinearRegression()
m3.fit(X_train3, y_train)
print('\nDropping RAD and TAX:')
print('Training data r-squared:', m3.score(X_train3, y_train))
print('Test data r-squared:', m3.score(X_test3, y_test))

#Model 4: dropping 'RM'
X_train3=X_train.drop(['RM'],axis=1)
X_test3=X_test.drop(['RM'],axis=1)
m3 = LinearRegression()
m3.fit(X_train3, y_train)
print('\nDropping RM:')
print('Training data r-squared:', m3.score(X_train3, y_train))
print('Test data r-squared:', m3.score(X_test3, y_test))
# Out:
# With all 13 features:
# Training data r-squared: 0.750121534530608
# Test data r-squared: 0.6709339839115642
#
# Dropping AGE and INDUS:
# Training data r-squared: 0.7493053373352907
# Test data r-squared: 0.6763654557506371
#
# Dropping RAD and TAX:
# Training data r-squared: 0.7368686640133163
# Test data r-squared: 0.6632010671410646
#
# Dropping RM:
# Training data r-squared: 0.7193887832617302
# Test data r-squared: 0.5888340028003314

# %% [markdown]
# - We conclude that dropping AGE and INDUS does not degrade the model, so these features are not effecting the predictions much and can be safely dropped.
# - Same is the case with RAD and TAX. You can also try dropping all 4.
# - But dropping RM causes performance to drop significantly, showing that it is a significant feature in prediction.

# %% [markdown]
# #Practice Problems

# %% [markdown]
# Question 1:
#
# 1. We intend to design a machine learning system for predicting humidity using temperature values as feature. The
# following table shows average temperature values and their corresponding average humidity values for 12 months of a
# year for a certain city.
# Feature
# Temperature (0C)
#
# 14.1 16.7 19.7 25.2 25.1 18.8 11.7 10.2 9.0 9.1 10.5 12.6
#
# Target
# Humidity (%)
#
# 44.3 50.4 46.8 33.7 37.4 54.2 68.2 69.0 45.0 51.3 20.7 24.4
#
# a. Write linear regression equation for the prediction system.
#
# b. Find predicted values for humidity i.e. h(x
# (i)
# ), if θ0 = 53.95 and θ1 = −0.56.
#
# c. Find the value of the cost function.
# d. Find R-squared value for this model.
# e. Propose two methods by which the R-squared value obtained in part c can be improved.
#
#
# question 2 includede

# %% [markdown]
# part(a)
#
# linear regression equation :
#     Predicted Humidity=θ0​+θ1​(Temperature)

# %% [markdown]
# part (b)
# b. Find predicted values for humidity i.e. h(x
# (i)
# ), if θ0 = 53.95 and θ1 = −0.56.

# %%
# Temperature (feature)
x = np.array([14.1,16.7,19.7,25.2,25.1,18.8,11.7,10.2,9.0,9.1,10.5,12.6])

# Humidity (actual target)
y = np.array([44.3,50.4,46.8,33.7,37.4,54.2,68.2,69.0,45.0,51.3,20.7,24.4])

# %%
# parameters given in question
theta_0 = 53.95
theta_1 = -0.56

def h(x):
    return theta_0 + theta_1 * x

# %%
# predicted values
y_pred = h(x)

print("Predicted Humidity Values:")
for i in range(len(x)):
    print(f"Temp: {x[i]} -> Predicted Humidity: {y_pred[i]:.2f}")
# Out:
# Predicted Humidity Values:
# Temp: 14.1 -> Predicted Humidity: 46.05
# Temp: 16.7 -> Predicted Humidity: 44.60
# Temp: 19.7 -> Predicted Humidity: 42.92
# Temp: 25.2 -> Predicted Humidity: 39.84
# Temp: 25.1 -> Predicted Humidity: 39.89
# Temp: 18.8 -> Predicted Humidity: 43.42
# Temp: 11.7 -> Predicted Humidity: 47.40
# Temp: 10.2 -> Predicted Humidity: 48.24
# Temp: 9.0 -> Predicted Humidity: 48.91
# Temp: 9.1 -> Predicted Humidity: 48.85
# Temp: 10.5 -> Predicted Humidity: 48.07
# Temp: 12.6 -> Predicted Humidity: 46.89

# %% [markdown]
# ##part(c) Cost Function
#
# the cost function is mse

# %%
def mse(y_true, y_pred):
    n = len(y_true)
    return np.sum((y_true - y_pred)**2) / n

cost = mse(y, y_pred)

print("\nCost Function (MSE):", cost)
# Out:
# Cost Function (MSE): 196.00181733333338

# %% [markdown]
# ##part(e) R squared value

# %%
def r_squared(y_true, y_pred):

    ss_res = np.sum((y_true - y_pred)**2)     # residual sum of squares
    ss_tot = np.sum((y_true - np.mean(y_true))**2)  # total sum of squares

    r2 = 1 - (ss_res / ss_tot)

    return r2

r2_score = r_squared(y, y_pred)

print("\nR-squared:", r2_score)
# Out:
# R-squared: 0.04750608140669721

# %%
test = LinearRegression()
test.fit(x.reshape(-1, 1), y)
test.score(x.reshape(-1, 1), y)
# Out:
# 0.047509823288706454

# %% [markdown]
# the function implemented and the builtin are yielding the same result.
#
# ##substitute for q3

# %% [markdown]
# ##part(e)
#
# Improve by:
#
# Adding more features
#
# Using a more complex regression model

# %% [markdown]
# ##question 5

# %%
fish_data = pd.read_csv("Dataset_Fish_Market.csv")

# %%
fish_data.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# suppose original column was 'Species'
le = LabelEncoder()

fish_data['Species'] = le.fit_transform(fish_data['Species'])

# %%
fish_data.head()
# Out:
#    Species  Weight  Length1  Length2  Length3   Height   Width
# 0        0   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1        0   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2        0   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3        0   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4        0   430.0     26.5     29.0     34.0  12.4440  5.1340

# %% [markdown]
# part(a) equation

# %% [markdown]
# h(x)=θ0​+θ1​⋅Length1+θ2​⋅Length2+θ3​⋅Length3+θ4​⋅Height+θ5​⋅Width+θ6​⋅Species

# %%
# Features and target
X = fish_data.drop("Weight", axis=1).values
y = fish_data["Weight"].values.reshape(-1, 1)

# Add intercept term
X_b = np.hstack([np.ones((X.shape[0],1)), X])

# Hypothesis function
def h(theta, X):
    """
    Compute predictions for given features X and parameters theta
    """
    return X @ theta  # matrix multiplication

# Mean Squared Error cost function
def compute_cost(theta, X, y):
    m = len(y)
    return (1/(2*m)) * np.sum((h(theta, X) - y)**2)

# Gradient Descent
def gradient_descent(X, y, lr=0.0001, n_iter=10000):
    m, n = X.shape
    theta = np.zeros((n,1))  # initialize parameters theta = [[0], [0], [0], [0], [0], [0], [0]]
    cost_history = []

    for i in range(n_iter):
        gradient = (1/m) * (X.T @ (h(theta, X) - y))
        theta -= lr * gradient
        if i % 1000 == 0:  # track cost every 1000 iterations
            cost_history.append(compute_cost(theta, X, y))
    return theta, cost_history

# Train model
theta_final, cost_history = gradient_descent(X_b, y, lr=0.0001, n_iter=10000)

print("Final parameters (θ0, θ1, ...):")
print(theta_final.flatten())

# Predictions
y_pred = h(theta_final, X_b)

# R-squared
ss_total = np.sum((y - y.mean())**2)
ss_res = np.sum((y - y_pred)**2)
r2 = 1 - (ss_res / ss_total)
print("R-squared:", r2)
# Out:
# Final parameters (θ0, θ1, ...):
# [-36.98506849 -55.88333401  21.00645891  10.60987413  -9.47179692
#   -2.54400659  12.6776227 ]
# R-squared: 0.7622795105895221

# %% [markdown]
# 1. The X_b contains all the feature values, the first column hold 1 for the bias value
# 2. initially the prediction will be 0 since theta = [[0], [0], [0], [0], [0], [0], [0]] initially and multiplying them with feature values yield zero

# %%
corr_matrix = pd.DataFrame(X, columns=fish_data.drop("Weight", axis=1).columns).corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Polynomial features (degree=2, include only squared terms)
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)
X_poly = poly.fit_transform(X)

# Names of features
original_feature_names = fish_data.drop("Weight", axis=1).columns
print("Polynomial features:", poly.get_feature_names_out(original_feature_names))

# Linear regression on polynomial features
lr_poly = LinearRegression()
lr_poly.fit(X_poly, y)

# Parameters
print("Intercept (θ0):", lr_poly.intercept_)
print("Coefficients:", lr_poly.coef_)

# R-squared
y_poly_pred = lr_poly.predict(X_poly)
r2_poly = r2_score(y, y_poly_pred)
print("R-squared (Polynomial):", r2_poly)
# Out:
# Polynomial features: ['Species' 'Length1' 'Length2' 'Length3' 'Height' 'Width' 'Species^2'
#  'Species Length1' 'Species Length2' 'Species Length3' 'Species Height'
#  'Species Width' 'Length1^2' 'Length1 Length2' 'Length1 Length3'
#  'Length1 Height' 'Length1 Width' 'Length2^2' 'Length2 Length3'
#  'Length2 Height' 'Length2 Width' 'Length3^2' 'Length3 Height'
#  'Length3 Width' 'Height^2' 'Height Width' 'Width^2']
# Intercept (θ0): [218.378388]
# Coefficients: [[ -40.1821154  -159.98143521   45.06160972   71.48276099  -74.48662983
#    157.47986838    6.59363058   29.43115566  -16.78031133  -10.66823555
#     20.38389506  -28.34553372  -76.93131705   93.38659442   40.9734897
#    -17.56322183   81.45360835   -8.30703597  -60.15422817   21.92993136
#    -63.80012957   11.0929573    -4.59754229  -17.71974364    2.24713744
#      3.39740607   15.91681663]]
# R-squared (Polynomial): 0.9850605305124668

# %% [markdown]
# ##question 6

# %% [markdown]
# degree 3

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Polynomial features (degree=3, include only squared terms)
poly = PolynomialFeatures(degree=3, include_bias=False, interaction_only=False)
X_poly = poly.fit_transform(X)

# Names of features
original_feature_names = fish_data.drop("Weight", axis=1).columns
print("Polynomial features:", poly.get_feature_names_out(original_feature_names))

# Linear regression on polynomial features
lr_poly = LinearRegression()
lr_poly.fit(X_poly, y)

# Parameters
print("Intercept (θ0):", lr_poly.intercept_)
print("Coefficients:", lr_poly.coef_)

# R-squared
y_poly_pred = lr_poly.predict(X_poly)
r2_poly = r2_score(y, y_poly_pred)
print("R-squared (Polynomial):", r2_poly)
# Out:
# Polynomial features: ['Species' 'Length1' 'Length2' 'Length3' 'Height' 'Width' 'Species^2'
#  'Species Length1' 'Species Length2' 'Species Length3' 'Species Height'
#  'Species Width' 'Length1^2' 'Length1 Length2' 'Length1 Length3'
#  'Length1 Height' 'Length1 Width' 'Length2^2' 'Length2 Length3'
#  'Length2 Height' 'Length2 Width' 'Length3^2' 'Length3 Height'
#  'Length3 Width' 'Height^2' 'Height Width' 'Width^2' 'Species^3'
#  'Species^2 Length1' 'Species^2 Length2' 'Species^2 Length3'
#  'Species^2 Height' 'Species^2 Width' 'Species Length1^2'
#  'Species Length1 Length2' 'Species Length1 Length3'
#  'Species Length1 Height' 'Species Length1 Width' 'Species Length2^2'
#  'Species Length2 Length3' 'Species Length2 Height'
#  'Species Length2 Width' 'Species Length3^2' 'Species Length3 Height'
#  'Species Length3 Width' 'Species Height^2' 'Species Height Width'
#  'Species Width^2' 'Length1^3' 'Length1^2 Length2' 'Length1^2 Length3'
#  'Length1^2 Height' 'Length1^2 Width' 'Length1 Length2^2'
#  'Length1 Length2 Length3' 'Length1 Length2 Height'
#  'Length1 Length2 Width' 'Length1 Length3^2' 'Length1 Length3 Height'
#  'Length1 Length3 Width' 'Length1 Height^2' 'Length1 Height Width'
#  'Length1 Width^2' 'Length2^3' 'Length2^2 Length3' 'Length2^2 Height'
#  'Length2^2 Width' 'Length2 Length3^2' 'Length2 Length3 Height'
#  'Length2 Length3 Width' 'Length2 Height^2' 'Length2 Height Width'
#  'Length2 Width^2' 'Length3^3' 'Length3^2 Height' 'Length3^2 Width'
#  'Length3 Height^2' 'Length3 Height Width' 'Length3 Width^2' 'Height^3'
#  'Height^2 Width' 'Height Width^2' 'Width^3']
# Intercept (θ0): [-597.0302941]
# Coefficients: [[-1.04094025e+02 -1.67178615e+03  2.37737611e+03 -6.25864711e+02
#    6.75186861e+01 -4.68108793e+02  1.38817748e+02  4.87795900e+02
#   -6.47429190e+02  1.24982817e+02  3.49789995e+01  1.04268859e+02
#   -1.66945253e+02  1.05566563e+03 -7.38757207e+02  4.57229955e+02
#    6.88812073e+01 -7.86144103e+02  5.40124210e+02 -2.16093985e+02
#   -3.38436369e+02  8.91404405e+01 -2.37087639e+02  3.42719269e+02
#    1.01312057e+02 -1.57672821e+02 -4.74231949e+01 -1.97655556e+01
#   -2.50008526e+01  3.06376192e+01 -4.30794063e-01 -1.91751859e+01
#    7.45718828e+00  7.96806872e+01 -3.00713359e+02  1.46417426e+02
#   -7.76128707e+01 -3.87884664e+00  2.12872116e+02 -1.29141839e+02
#    2.17589340e+01  5.64528087e+01 -7.79144830e+00  5.90133357e+01
#   -7.23874313e+01 -2.66171470e+01  3.22385748e+01  2.65314468e+01
#   -3.57077922e+02  7.92300245e+02  1.29570449e+02 -3.74297405e+01
#    3.76850948e+02 -6.39458143e+02 -4.82161736e+01 -8.14739377e+01
#   -6.81340882e+02 -9.64535428e+01  1.47075523e+02 -6.17511715e+01
#   -3.95715997e+01  6.41081611e-01  1.65509251e+02  1.56647319e+02
#    3.09178051e+01  6.52311192e+01  4.50949670e+02  1.01150704e+01
#   -5.99556289e+01 -1.87449986e+02 -1.12547110e+01  1.72924179e+02
#   -3.62861518e+02  2.12941357e+01 -3.47666696e+01  1.05289168e+02
#    4.73881452e+01 -1.60841159e+02  1.80570877e+02 -1.27980496e+01
#    4.04447498e+01 -6.27165183e+01  6.49734942e+01]]
# R-squared (Polynomial): 0.9943439291526555

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Polynomial features (degree=9, include only squared terms)
poly = PolynomialFeatures(degree=9, include_bias=False, interaction_only=False)
X_poly = poly.fit_transform(X)

# Names of features
original_feature_names = fish_data.drop("Weight", axis=1).columns
print("Polynomial features:", poly.get_feature_names_out(original_feature_names))

# Linear regression on polynomial features
lr_poly = LinearRegression()
lr_poly.fit(X_poly, y)

# Parameters
print("Intercept (θ0):", lr_poly.intercept_)
print("Coefficients:", lr_poly.coef_)

# R-squared
y_poly_pred = lr_poly.predict(X_poly)
r2_poly = r2_score(y, y_poly_pred)
print("R-squared (Polynomial):", r2_poly)
# Out:
# Polynomial features: ['Species' 'Length1' 'Length2' ... 'Height^2 Width^7' 'Height Width^8'
#  'Width^9']
# Intercept (θ0): [-2.51861971]
# Coefficients: [[-1.65388349e-10  9.98943514e-12  1.92044064e-11 ...  1.61870687e-08
#    1.06395405e-08  5.59863770e-09]]
# R-squared (Polynomial): 0.9999155317327126

# %% [markdown]
# Increasing polynomial degree → more features → more flexibility to fit data
#
# High degree → risk of overfitting → training R² is very high, but test/generalization may drop
#
# Wall-time increases with degree → higher computational cost
